# %%
# analysis.ipynb

"""
Analysis Script
Author: Imran Feisal
Date: 31/10/2024
Description:
This Jupyter notebook performs clustering and visualization on the latent features
and TabNet predictions, uses advanced clustering methods to determine the optimal
number of clusters, selects the best clustering algorithm based on validation metrics,
and provides in-depth analysis.

Inspiration: 
- Xu, Y., Goodacre, S., & Hall, M. (2018). Developing a Dynamic Health Index Using Machine Learning to Predict Patient Deterioration. IEEE Journal of Biomedical and Health Informatics, 22(3), 919-925.
- McInnes, L., Healy, J., & Melville, J. (2018). UMAP: Uniform Manifold Approximation and Projection for Dimension Reduction. arXiv preprint arXiv:1802.03426.
"""
# Out:
# '\nAnalysis Script\nAuthor: Imran Feisal\nDate: 31/10/2024\nDescription:\nThis Jupyter notebook performs clustering and visualization on the latent features\nand TabNet predictions, uses advanced clustering methods to determine the optimal\nnumber of clusters, selects the best clustering algorithm based on validation metrics,\nand provides in-depth analysis.\n\nInspiration: \n- Xu, Y., Goodacre, S., & Hall, M. (2018). Developing a Dynamic Health Index Using Machine Learning to Predict Patient Deterioration. IEEE Journal of Biomedical and Health Informatics, 22(3), 919-925.\n- McInnes, L., Healy, J., & Melville, J. (2018). UMAP: Uniform Manifold Approximation and Projection for Dimension Reduction. arXiv preprint arXiv:1802.03426.\n'

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from scipy.stats import shapiro, levene, f_oneway, kruskal
import umap.umap_ as umap
import warnings


warnings.filterwarnings('ignore')

# %% [markdown]
# # Set random seed for reproducibility

# %%
np.random.seed(42)

# %%
# Load data
latent_features = pd.read_csv('latent_features_vae.csv')
tabnet_predictions = pd.read_csv('tabnet_predictions.csv')
data = latent_features.merge(tabnet_predictions, on='Id', how='inner')
X = data.drop(columns=['Id', 'Predicted_Health_Index'])

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# ------------------------------
# KMeans Clustering
# ------------------------------

silhouette_scores_kmeans = []
cluster_range = range(2, 15)
for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    silhouette = silhouette_score(X_scaled, labels)
    silhouette_scores_kmeans.append(silhouette)

# Plot Silhouette Scores
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, silhouette_scores_kmeans, marker='o')
plt.title('Silhouette Scores for KMeans Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %%
# Select the second-best silhouette score
sorted_indices = np.argsort(silhouette_scores_kmeans)[::-1]
second_best_index = sorted_indices[1]  # Second-best score
optimal_clusters_kmeans = cluster_range[second_best_index]
print(f"Second-best number of clusters for KMeans: {optimal_clusters_kmeans}")

# Perform KMeans clustering with the second-best number of clusters
kmeans = KMeans(n_clusters=optimal_clusters_kmeans, random_state=42)
kmeans_labels = kmeans.fit_predict(X_scaled)
# Out:
# Second-best number of clusters for KMeans: 9

# %%
# ------------------------------
# DBSCAN Clustering
# ------------------------------

nearest_neighbors = NearestNeighbors(n_neighbors=5)
neighbors = nearest_neighbors.fit(X_scaled)
distances, indices = neighbors.kneighbors(X_scaled)
distances = np.sort(distances[:, 4], axis=0)

plt.figure(figsize=(10, 6))
plt.plot(distances)
plt.title('k-distance Graph for DBSCAN')
plt.xlabel('Data Points sorted by distance')
plt.ylabel('5th Nearest Neighbor Distance')
plt.show()

# %%
# From the plot, choose an epsilon value where the distance starts to increase sharply
epsilon = 1.5  # Adjust based on the k-distance graph
dbscan = DBSCAN(eps=epsilon, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_scaled)

# %%
# ------------------------------
# Cluster Validation Metrics
# ------------------------------
silhouette_kmeans = silhouette_score(X_scaled, kmeans_labels)
ch_score_kmeans = calinski_harabasz_score(X_scaled, kmeans_labels)
db_score_kmeans = davies_bouldin_score(X_scaled, kmeans_labels)

validation_scores = pd.DataFrame({
    'Clustering_Method': ['KMeans', 'DBSCAN'],
    'Silhouette_Score': [silhouette_kmeans, np.nan],  # DBSCAN might not have valid silhouette
    'Calinski_Harabasz_Score': [ch_score_kmeans, np.nan],
    'Davies_Bouldin_Score': [db_score_kmeans, np.nan]
})

display(validation_scores)
# Out:
#   Clustering_Method  Silhouette_Score  Calinski_Harabasz_Score  \
# 0            KMeans          0.324637             20636.928197
# 1            DBSCAN               NaN                      NaN
#
#    Davies_Bouldin_Score
# 0              1.259277
# 1                   NaN

# %%
# Assign Clusters and Map Severity Index
data['Cluster'] = kmeans_labels
data = data[data['Cluster'] != -1]
cluster_severity = data.groupby('Cluster')['Predicted_Health_Index'].mean().sort_values().reset_index()
cluster_severity['Severity_Index'] = range(1, len(cluster_severity) + 1)
severity_mapping = cluster_severity.set_index('Cluster')['Severity_Index'].to_dict()
data['Severity_Index'] = data['Cluster'].map(severity_mapping)

# %%
# ------------------------------
# t-SNE Visualization
# ------------------------------

tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
tsne_results = tsne.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=tsne_results[:, 0], y=tsne_results[:, 1], hue=data['Severity_Index'], palette='viridis')
plt.title('t-SNE Visualization of Latent Features (KMeans)')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Severity Index')
plt.show()

# %%
# ------------------------------
# UMAP Visualization
# ------------------------------
reducer = umap.UMAP(n_components=2, random_state=42)
umap_results = reducer.fit_transform(X_scaled)

plt.figure(figsize=(10, 6))
sns.scatterplot(x=umap_results[:, 0], y=umap_results[:, 1], hue=data['Severity_Index'], palette='viridis')
plt.title('UMAP Visualization of Latent Features (KMeans)')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.legend(title='Severity Index')
plt.show()

# %%
# ------------------------------
# Statistical Analysis
# ------------------------------
normality_pvalues = []
for cluster in data['Cluster'].unique():
    cluster_data = data[data['Cluster'] == cluster]['Predicted_Health_Index']
    stat, p = shapiro(cluster_data)
    normality_pvalues.append(p)

# If any p-value is less than 0.05, normality is violated
if any(p < 0.05 for p in normality_pvalues):
    print("Normality assumption violated in at least one cluster. Using Kruskal-Wallis test.")
    # Perform Kruskal-Wallis test
    kruskal_result = kruskal(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
    print(f"Kruskal-Wallis H-statistic: {kruskal_result.statistic:.4f}, p-value: {kruskal_result.pvalue:.4e}")
else:
    # Check homogeneity of variances
    stat, p = levene(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
    if p < 0.05:
        print("Homogeneity of variances assumption violated. Using Kruskal-Wallis test.")
        # Perform Kruskal-Wallis test
        kruskal_result = kruskal(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
        print(f"Kruskal-Wallis H-statistic: {kruskal_result.statistic:.4f}, p-value: {kruskal_result.pvalue:.4e}")
    else:
        # Perform ANOVA
        anova_result = f_oneway(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
        print(f"ANOVA F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4e}")
# Out:
# Normality assumption violated in at least one cluster. Using Kruskal-Wallis test.
# Kruskal-Wallis H-statistic: 66927.7061, p-value: 0.0000e+00

# %%
# ------------------------------
# Save Analysis Results
# ------------------------------


# Save Results
data.to_csv('analysis_results.csv', index=False)
print("Analysis results saved.")
# Out:
# Analysis results saved.

# %%
# analysis.py
# Modified Analysis Script
# Author: Imran Feisal
# Date: 31/10/2024
# Description:
# Updated to remove Agglomerative Clustering and use the second-best silhouette score for KMeans.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
from scipy.stats import shapiro, levene, f_oneway, kruskal
from scikit_posthocs import posthoc_dunn
import umap.umap_ as umap
import warnings

warnings.filterwarnings('ignore')

# Set random seed for reproducibility
np.random.seed(42)

# Load data
latent_features = pd.read_csv('latent_features_vae.csv')
tabnet_predictions = pd.read_csv('tabnet_predictions.csv')
data = latent_features.merge(tabnet_predictions, on='Id', how='inner')
X = data.drop(columns=['Id', 'Predicted_Health_Index'])

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# KMeans Clustering
silhouette_scores_kmeans = []
cluster_range = range(2, 15)
for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    silhouette = silhouette_score(X_scaled, labels)
    silhouette_scores_kmeans.append(silhouette)

# Plot Silhouette Scores
plt.figure(figsize=(10, 6))
plt.plot(cluster_range, silhouette_scores_kmeans, marker='o')
plt.title('Silhouette Scores for KMeans Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# Select the second-best silhouette score
sorted_indices = np.argsort(silhouette_scores_kmeans)[::-1]
second_best_index = sorted_indices[1]  # Second-best score
optimal_clusters_kmeans = cluster_range[second_best_index]
print(f"Second-best number of clusters for KMeans: {optimal_clusters_kmeans}")

# Perform KMeans clustering with the second-best number of clusters
kmeans = KMeans(n_clusters=optimal_clusters_kmeans, random_state=42)
kmeans_labels = kmeans.fit_predict(X_scaled)

# DBSCAN Clustering
nearest_neighbors = NearestNeighbors(n_neighbors=5)
neighbors = nearest_neighbors.fit(X_scaled)
distances, indices = neighbors.kneighbors(X_scaled)
distances = np.sort(distances[:, 4], axis=0)

plt.figure(figsize=(10, 6))
plt.plot(distances)
plt.title('k-distance Graph for DBSCAN')
plt.xlabel('Data Points sorted by distance')
plt.ylabel('5th Nearest Neighbor Distance')
plt.show()

epsilon = 1.5  # Adjust based on the k-distance graph
dbscan = DBSCAN(eps=epsilon, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_scaled)

# Validation Metrics
silhouette_kmeans = silhouette_score(X_scaled, kmeans_labels)
ch_score_kmeans = calinski_harabasz_score(X_scaled, kmeans_labels)
db_score_kmeans = davies_bouldin_score(X_scaled, kmeans_labels)

validation_scores = pd.DataFrame({
    'Clustering_Method': ['KMeans', 'DBSCAN'],
    'Silhouette_Score': [silhouette_kmeans, np.nan],  # DBSCAN might not have valid silhouette
    'Calinski_Harabasz_Score': [ch_score_kmeans, np.nan],
    'Davies_Bouldin_Score': [db_score_kmeans, np.nan]
})

display(validation_scores)

# Assign Clusters and Map Severity Index
data['Cluster'] = kmeans_labels
data = data[data['Cluster'] != -1]
cluster_severity = data.groupby('Cluster')['Predicted_Health_Index'].mean().sort_values().reset_index()
cluster_severity['Severity_Index'] = range(1, len(cluster_severity) + 1)
severity_mapping = cluster_severity.set_index('Cluster')['Severity_Index'].to_dict()
data['Severity_Index'] = data['Cluster'].map(severity_mapping)

# Statistical Analysis
# Check assumptions for ANOVA
# 1. Normality within each group
normality_pvalues = []
for cluster in data['Cluster'].unique():
    cluster_data = data[data['Cluster'] == cluster]['Predicted_Health_Index']
    stat, p = shapiro(cluster_data)
    normality_pvalues.append(p)

# If any p-value is less than 0.05, normality is violated
if any(p < 0.05 for p in normality_pvalues):
    print("Normality assumption violated in at least one cluster. Using Kruskal-Wallis test.")
    # Perform Kruskal-Wallis test
    kruskal_result = kruskal(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
    print(f"Kruskal-Wallis H-statistic: {kruskal_result.statistic:.4f}, p-value: {kruskal_result.pvalue:.4e}")

    # Post hoc analysis using Dunn's test
    posthoc_results = posthoc_dunn(data, val_col='Predicted_Health_Index', group_col='Cluster', p_adjust='bonferroni')
    print("Post hoc Dunn's test results:")
    print(posthoc_results)
else:
    # Check homogeneity of variances
    stat, p = levene(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
    if p < 0.05:
        print("Homogeneity of variances assumption violated. Using Kruskal-Wallis test.")
        # Perform Kruskal-Wallis test
        kruskal_result = kruskal(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
        print(f"Kruskal-Wallis H-statistic: {kruskal_result.statistic:.4f}, p-value: {kruskal_result.pvalue:.4e}")

        # Post hoc analysis using Dunn's test
        posthoc_results = posthoc_dunn(data, val_col='Predicted_Health_Index', group_col='Cluster', p_adjust='bonferroni')
        print("Post hoc Dunn's test results:")
        print(posthoc_results)
    else:
        # Perform ANOVA
        anova_result = f_oneway(*(data[data['Cluster'] == cluster]['Predicted_Health_Index'] for cluster in data['Cluster'].unique()))
        print(f"ANOVA F-statistic: {anova_result.statistic:.4f}, p-value: {anova_result.pvalue:.4e}")

# Visualization of Cluster Differences
plt.figure(figsize=(12, 6))
sns.boxplot(x='Cluster', y='Predicted_Health_Index', data=data, palette='viridis')
plt.title('Boxplot of Predicted Health Index by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Predicted Health Index')
plt.show()

# t-SNE Visualization
tsne = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000)
tsne_results = tsne.fit_transform(X_scaled)
plt.figure(figsize=(10, 6))
sns.scatterplot(x=tsne_results[:, 0], y=tsne_results[:, 1], hue=data['Severity_Index'], palette='viridis')
plt.title('t-SNE Visualization of Latent Features (KMeans)')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Severity Index')
plt.show()

# UMAP Visualization
reducer = umap.UMAP(n_components=2, random_state=42)
umap_results = reducer.fit_transform(X_scaled)
plt.figure(figsize=(10, 6))
sns.scatterplot(x=umap_results[:, 0], y=umap_results[:, 1], hue=data['Severity_Index'], palette='viridis')
plt.title('UMAP Visualization of Latent Features (KMeans)')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.legend(title='Severity Index')
plt.show()

# Save Results
data.to_csv('analysis_results.csv', index=False)
print("Analysis results saved.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 19
#      17 from sklearn.neighbors import NearestNeighbors
#      18 from scipy.stats import shapiro, levene, f_oneway, kruskal
# ---> 19 from scikit_posthocs import posthoc_dunn
#      20 import umap.umap_ as umap
#      21 import warnings
#
# ModuleNotFoundError: No module named 'scikit_posthocs'

# %%
import os
import pandas as pd

# Directory containing the CSV files
directory = 'E:\synthea-master\output\csv\conditions.csv'

csv_file = pd.read_csv(directory)

csv_file.head()

unique_codes = csv_file[['CODE', 'DESCRIPTION']].drop_duplicates()
unique_codes_list = unique_codes.values.tolist()
unique_codes_list
# Out:
# [[314529007, 'Medication review due (situation)'],
#  [195662009, 'Acute viral pharyngitis (disorder)'],
#  [10509002, 'Acute bronchitis (disorder)'],
#  [109570002, 'Primary dental caries (disorder)'],
#  [66383009, 'Gingivitis (disorder)'],
#  [18718003, 'Gingival disease (disorder)'],
#  [125605004, 'Fracture of bone (disorder)'],
#  [263102004, 'Fracture subluxation of wrist (disorder)'],
#  [160968000, 'Risk activity involvement (finding)'],
#  [43878008, 'Streptococcal sore throat (disorder)'],
#  [427898007, 'Infection of tooth (disorder)'],
#  [444814009, 'Viral sinusitis (disorder)'],
#  [60234000, 'Aortic valve regurgitation (disorder)'],
#  [40055000, 'Chronic sinusitis (disorder)'],
#  [110030002, 'Concussion injury of brain (disorder)'],
#  [62564004, 'Concussion with loss of consciousness (disorder)'],
#  [840544004,
#   'Suspected disease caused by Severe acute respiratory coronavirus 2 (situation)'],
#  [248595008, 'Sputum finding (finding)'],
#  [43724002, 'Chill (finding)'],
#  [386661006, 'Fever (finding)'],
#  [840539006,
#   'Disease caused by severe acute respiratory syndrome coronavirus 2 (disorder)'],
#  [127294003, 'Traumatic or nontraumatic brain injury (disorder)'],
#  [105531004, 'Housing unsatisfactory (finding)'],
#  [224299000, 'Received higher education (finding)'],
#  [160903007, 'Full-time employment (finding)'],
#  [24079001, 'Atopic dermatitis (disorder)'],
#  [232353008, 'Perennial allergic rhinitis with seasonal variation (disorder)'],
#  [160904001, 'Part-time employment (finding)'],
#  [73595000, 'Stress (finding)'],
#  [473461003, 'Educated to high school level (finding)'],
#  [706893006, 'Victim of intimate partner abuse (finding)'],
#  [196416002, 'Impacted molars (disorder)'],
#  [82423001, 'Chronic pain (finding)'],
#  [124171000119105, 'Chronic intractable migraine without aura (disorder)'],
#  [32911000, 'Homeless (finding)'],
#  [224295006, 'Only received primary school education (finding)'],
#  [266934004, 'Transport problem (finding)'],
#  [278860009, 'Chronic low back pain (finding)'],
#  [72892002, 'Normal pregnancy (finding)'],
#  [271737000, 'Anemia (disorder)'],
#  [6525002, 'Dependent drug abuse (disorder)'],
#  [307426000, 'Acute infective cystitis (disorder)'],
#  [73438004, 'Unemployed (finding)'],
#  [741062008, 'Not in labor force (finding)'],
#  [55680006, 'Drug overdose'],
#  [422650009, 'Social isolation (finding)'],
#  [713458007, 'Lack of access to transportation (finding)'],
#  [62106007, 'Concussion with no loss of consciousness (disorder)'],
#  [278558000, 'Dental filling lost (finding)'],
#  [233678006, 'Childhood asthma (disorder)'],
#  [423315002, 'Limited social contact (finding)'],
#  [198992004, 'Eclampsia in pregnancy (disorder)'],
#  [10939881000119105, 'Unhealthy alcohol drinking behavior (finding)'],
#  [80583007, 'Severe anxiety (panic) (finding)'],
#  [428251008, 'History of appendectomy (situation)'],
#  [361055000, 'Misuses drugs (finding)'],
#  [36971009, 'Sinusitis (disorder)'],
#  [65363002, 'Otitis media (disorder)'],
#  [75498004, 'Acute bacterial sinusitis (disorder)'],
#  [81629009, 'Traumatic dislocation of temporomandibular joint (disorder)'],
#  [278602001, 'Loose dental filling (finding)'],
#  [424393004, 'Reports of violence in the environment (finding)'],
#  [1121000119107, 'Chronic neck pain (finding)'],
#  [714628002, 'Prediabetes (finding)'],
#  [59621000, 'Essential hypertension (disorder)'],
#  [37320007, 'Loss of teeth (disorder)'],
#  [67787004, 'Tongue tie (disorder)'],
#  [1187604002, 'Serving in military service (finding)'],
#  [161744009, 'Past pregnancy history of miscarriage (situation)'],
#  [427419006, 'Transformed migraine (disorder)'],
#  [162864005, 'Body mass index 30+ - obesity (finding)'],
#  [241929008, 'Acute allergic reaction (disorder)'],
#  [278598003, 'Leaking dental filling (finding)'],
#  [49727002, 'Cough (finding)'],
#  [431855005, 'Chronic kidney disease stage 1 (disorder)'],
#  [127013003, 'Disorder of kidney due to diabetes mellitus (disorder)'],
#  [48333001, 'Burn injury (morphologic abnormality)'],
#  [403190006, 'Epidermal burn of skin (disorder)'],
#  [312608009, 'Laceration - injury (disorder)'],
#  [284551006, 'Laceration of foot (disorder)'],
#  [398254007, 'Pre-eclampsia (disorder)'],
#  [266948004, 'Has a criminal record (finding)'],
#  [183996000, 'Sterilization requested (situation)'],
#  [267020005, 'History of tubal ligation (situation)'],
#  [384709000, 'Sprain (morphologic abnormality)'],
#  [70704007, 'Sprain of wrist (disorder)'],
#  [44465007, 'Sprain of ankle (disorder)'],
#  [5602001, 'Opioid abuse (disorder)'],
#  [19169002, 'Miscarriage in first trimester (disorder)'],
#  [79586000, 'Tubal pregnancy (disorder)'],
#  [278588009, 'Fractured dental filling (finding)'],
#  [61804006, 'Alveolitis of jaw (disorder)'],
#  [307731004, 'Injury of tendon of the rotator cuff of shoulder (disorder)'],
#  [239872002, 'Osteoarthritis of hip (disorder)'],
#  [39898005, 'Sleep disorder (disorder)'],
#  [73430006, 'Sleep apnea (disorder)'],
#  [237602007, 'Metabolic syndrome X (disorder)'],
#  [156073000, 'Complete miscarriage (disorder)'],
#  [55822004, 'Hyperlipidemia (disorder)'],
#  [91302008, 'Sepsis (disorder)'],
#  [76571007, 'Septic shock (disorder)'],
#  [67782005, 'Acute respiratory distress syndrome (disorder)'],
#  [58150001, 'Fracture of clavicle (disorder)'],
#  [401303003, 'Acute ST segment elevation myocardial infarction (disorder)'],
#  [399211009, 'History of myocardial infarction (situation)'],
#  [33737001, 'Fracture of rib (disorder)'],
#  [431856006, 'Chronic kidney disease stage 2 (disorder)'],
#  [90781000119102,
#   'Microalbuminuria due to type 2 diabetes mellitus (disorder)'],
#  [433144002, 'Chronic kidney disease stage 3 (disorder)'],
#  [157141000119108, 'Proteinuria due to type 2 diabetes mellitus (disorder)'],
#  [698306007, 'Awaiting transplantation of kidney (situation)'],
#  [48724000, 'Mitral valve regurgitation (disorder)'],
#  [239873007, 'Osteoarthritis of knee (disorder)'],
#  [431857002, 'Chronic kidney disease stage 4 (disorder)'],
#  [78275009, 'Obstructive sleep apnea syndrome (disorder)'],
#  [414545008, 'Ischemic heart disease (disorder)'],
#  [274531002,
#   'Abnormal findings diagnostic imaging heart+coronary circulat (finding)'],
#  [87433001, 'Pulmonary emphysema (disorder)'],
#  [60573004, 'Aortic valve stenosis (disorder)'],
#  [283371005, 'Laceration of forearm (disorder)'],
#  [284549007, 'Laceration of hand (disorder)'],
#  [46752004, 'Torus palatinus (disorder)'],
#  [7200002, 'Alcoholism (disorder)'],
#  [68496003, 'Polyp of colon (disorder)'],
#  [403191005, 'Partial thickness burn (disorder)'],
#  [11625007, 'Torus mandibularis (disorder)'],
#  [315268008, 'Suspected prostate cancer (situation)'],
#  [126906006, 'Neoplasm of prostate (disorder)'],
#  [92691004, 'Carcinoma in situ of prostate (disorder)'],
#  [1255252008,
#   'Resorption of alveolar process due to dental trauma (disorder)'],
#  [399261000, 'History of coronary artery bypass grafting (situation)'],
#  [162573006, 'Suspected lung cancer (situation)'],
#  [254637007, 'Non-small cell lung cancer (disorder)'],
#  [424132000, 'Non-small cell carcinoma of lung  TNM stage 1 (disorder)'],
#  [26929004, "Alzheimer's disease (disorder)"],
#  [197927001, 'Recurrent urinary tract infection (disorder)'],
#  [90460009, 'Injury of neck (disorder)'],
#  [39848009, 'Whiplash injury to neck (disorder)'],
#  [233604007, 'Pneumonia (disorder)'],
#  [876882001, 'Died in hospice (finding)'],
#  [161665007, 'History of renal transplant (situation)'],
#  [446654005, 'Refugee (person)'],
#  [185086009, 'Chronic obstructive bronchitis (disorder)'],
#  [64859006, 'Osteoporosis (disorder)'],
#  [74400008, 'Appendicitis (disorder)'],
#  [35999006, 'Blighted ovum (disorder)'],
#  [44054006, 'Diabetes mellitus type 2 (disorder)'],
#  [302870006, 'Hypertriglyceridemia (disorder)'],
#  [125601008, 'Injury of knee (disorder)'],
#  [444470001, 'Injury of anterior cruciate ligament (disorder)'],
#  [68962001, 'Muscle pain (finding)'],
#  [57676002, 'Joint pain (finding)'],
#  [283385000, 'Laceration of thigh (disorder)'],
#  [713197008, 'Recurrent rectal polyp (disorder)'],
#  [109838007, 'Overlapping malignant neoplasm of colon (disorder)'],
#  [80394007, 'Hyperglycemia (disorder)'],
#  [201834006, 'Localized  primary osteoarthritis of the hand (disorder)'],
#  [22298006, 'Myocardial infarction (disorder)'],
#  [88805009, 'Chronic congestive heart failure (disorder)'],
#  [367498001, 'Seasonal allergic rhinitis (disorder)'],
#  [27942005, 'Shock (disorder)'],
#  [254837009, 'Malignant neoplasm of breast (disorder)'],
#  [203082005, 'Fibromyalgia (disorder)'],
#  [85116003, 'Miscarriage in second trimester (disorder)'],
#  [267253006, 'Fetus with chromosomal abnormality (disorder)'],
#  [368581000119106, 'Neuropathy due to type 2 diabetes mellitus (disorder)'],
#  [45816000, 'Pyelonephritis (disorder)'],
#  [389087006, 'Hypoxemia (disorder)'],
#  [271825005, 'Respiratory distress (finding)'],
#  [706870000, 'Acute pulmonary embolism (disorder)'],
#  [36955009, 'Loss of taste (finding)'],
#  [267036007, 'Dyspnea (finding)'],
#  [56018004, 'Wheezing (finding)'],
#  [49436004, 'Atrial fibrillation (disorder)'],
#  [401314000,
#   'Acute non-ST segment elevation myocardial infarction (disorder)'],
#  [95417003, 'Primary fibromyalgia syndrome (disorder)'],
#  [25064002, 'Headache (finding)'],
#  [422587007, 'Nausea (finding)'],
#  [249497008, 'Vomiting symptom (finding)'],
#  [132281000119108, 'Acute deep venous thrombosis (disorder)'],
#  [370247008, 'Facial laceration (disorder)'],
#  [93761005, 'Primary malignant neoplasm of colon (disorder)'],
#  [46177005, 'End-stage renal disease (disorder)'],
#  [65966004, 'Fracture of forearm (disorder)'],
#  [84229001, 'Fatigue (finding)'],
#  [267060006, 'Diarrhea symptom (finding)'],
#  [56786000, 'Pulmonic valve stenosis (disorder)'],
#  [30832001, 'Rupture of patellar tendon (disorder)'],
#  [90560007,
#   'Inflammatory disorder due to increased blood urate level (disorder)'],
#  [263172003, 'Fracture of mandible (disorder)'],
#  [86406008, 'Human immunodeficiency virus infection (disorder)'],
#  [61977001, 'Chronic type B viral hepatitis (disorder)'],
#  [428915008, 'Toxoplasma gondii antibody detected (finding)'],
#  [192127007, 'Child attention deficit disorder (disorder)'],
#  [68235000, 'Nasal congestion (finding)'],
#  [1231000119100, 'History of aortic valve replacement (situation)'],
#  [128613002, 'Seizure disorder (disorder)'],
#  [1290882004, 'History of seizure (situation)'],
#  [69896004, 'Rheumatoid arthritis (disorder)'],
#  [84757009, 'Epilepsy (disorder)'],
#  [161679004, 'History of artificial joint (situation)'],
#  [65710008, 'Acute respiratory failure (disorder)'],
#  [16114001, 'Fracture of ankle (disorder)'],
#  [37849005, 'Congenital uterine anomaly (disorder)'],
#  [443165006, 'Osteoporotic fracture of bone (disorder)'],
#  [770349000, 'Sepsis caused by virus (disorder)'],
#  [234466008, 'Acquired coagulation disorder (disorder)'],
#  [84114007, 'Heart failure (disorder)'],
#  [213150003, 'Kidney transplant failure and rejection (disorder)'],
#  [422034002, 'Retinopathy due to type 2 diabetes mellitus (disorder)'],
#  [1551000119108,
#   'Nonproliferative retinopathy due to type 2 diabetes mellitus (disorder)'],
#  [97331000119101,
#   'Macular edema and retinopathy due to type 2 diabetes mellitus (disorder)'],
#  [1501000119109,
#   'Proliferative retinopathy due to type 2 diabetes mellitus (disorder)'],
#  [128188000, 'Cerebral palsy (disorder)'],
#  [398152000, 'Poor muscle tone (finding)'],
#  [221360009, 'Spasticity (finding)'],
#  [235595009, 'Gastroesophageal reflux disease (disorder)'],
#  [83664006, 'Idiopathic atrophic hypothyroidism (disorder)'],
#  [363406005, 'Malignant neoplasm of colon (disorder)'],
#  [408512008, 'Body mass index 40+ - severely obese (finding)'],
#  [359817006, 'Closed fracture of hip (disorder)'],
#  [429280009, 'History of amputation of foot (situation)'],
#  [449868002, 'Smokes tobacco daily (finding)'],
#  [40275004, 'Contact dermatitis (disorder)'],
#  [444448004, 'Injury of medial collateral ligament of knee (disorder)'],
#  [4557003, 'Preinfarction syndrome (disorder)'],
#  [127295002, 'Traumatic brain injury (disorder)'],
#  [93143009, 'Leukemia  disease (disorder)'],
#  [230265002, "Familial Alzheimer's disease of early onset (disorder)"],
#  [698303004, 'Awaiting transplantation of bone marrow (situation)'],
#  [86175003, 'Injury of heart (disorder)'],
#  [446096008, 'Perennial allergic rhinitis (disorder)'],
#  [204949001, 'Renal dysplasia (disorder)'],
#  [152621000119105,
#   'History of allotransplantation of bone marrow (situation)'],
#  [230690007, 'Cerebrovascular accident (disorder)'],
#  [254632001, 'Small cell carcinoma of lung (disorder)'],
#  [67811000119102,
#   'Primary small cell malignant neoplasm of lung  TNM stage 1 (disorder)'],
#  [267102003, 'Sore throat (finding)'],
#  [283545005, 'Gunshot wound (disorder)'],
#  [262574004, 'Bullet wound (disorder)'],
#  [370143000, 'Major depressive disorder (disorder)'],
#  [153351000119102, 'History of peripheral stem cell transplant (situation)'],
#  [312157006, 'Infectious mediastinitis (disorder)'],
#  [6072007, 'Bleeding from anus (disorder)'],
#  [236077008, 'Protracted diarrhea (finding)'],
#  [707418001, 'Male infertility due to cystic fibrosis (disorder)'],
#  [190905008, 'Cystic fibrosis (disorder)'],
#  [239720000, 'Tear of meniscus of knee (disorder)'],
#  [427089005, 'Diabetes mellitus due to cystic fibrosis (disorder)'],
#  [94503003, 'Metastatic malignant neoplasm to prostate (disorder)'],
#  [262521009,
#   'Traumatic injury of spinal cord and/or vertebral column (disorder)'],
#  [1734006, 'Fracture of vertebral column with spinal cord injury (disorder)'],
#  [246677007, 'Passive conjunctival congestion (finding)'],
#  [609496007, 'Complication occurring during pregnancy (disorder)'],
#  [47693006, 'Rupture of appendix (disorder)'],
#  [22253000, 'Pain (finding)'],
#  [110359009, 'Intellectual disability (disorder)'],
#  [157265008, 'Dislocation of hip joint (disorder)'],
#  [66857006, 'Hemoptysis (finding)'],
#  [65275009, 'Acute cholecystitis (disorder)'],
#  [235919008, 'Gallbladder calculus (disorder)'],
#  [53827007, 'Excessive salivation (disorder)'],
#  [62718007, 'Dribbling from mouth (finding)'],
#  [14760008, 'Constipation (finding)'],
#  [36923009, 'Major depression  single episode (disorder)'],
#  [15802004, 'Dystonia (disorder)'],
#  [15724005,
#   'Fracture of vertebral column without spinal cord injury (disorder)'],
#  [94260004, 'Metastatic malignant neoplasm to colon (disorder)'],
#  [62479008, 'Acquired immune deficiency syndrome (disorder)'],
#  [47505003, 'Posttraumatic stress disorder (disorder)'],
#  [40095003, 'Injury of kidney (disorder)'],
#  [87628006, 'Bacterial infectious disease (disorder)'],
#  [195967001, 'Asthma (disorder)'],
#  [108631000119101, 'History of autologous bone marrow transplant (situation)'],
#  [160701002, 'Social migrant (finding)'],
#  [403192003, 'Full thickness burn (disorder)'],
#  [91434003, 'Pulmonic valve regurgitation (disorder)'],
#  [109989006, 'Multiple myeloma (disorder)'],
#  [60951000119105, 'Blindness due to type 2 diabetes mellitus (disorder)'],
#  [128302006, 'Chronic hepatitis C (disorder)'],
#  [414667000, 'Meningomyelocele (disorder)'],
#  [373587001, 'Chiari malformation type II (disorder)'],
#  [302297009, 'Congenital deformity of foot (disorder)'],
#  [298382003, 'Scoliosis deformity of spine (disorder)'],
#  [68566005, 'Urinary tract infectious disease (disorder)'],
#  [399912005, 'Pressure ulcer (disorder)'],
#  [707577004, 'Female infertility due to cystic fibrosis (disorder)'],
#  [288959006, 'Unable to swallow saliva (finding)'],
#  [91861009, 'Acute myeloid leukemia (disorder)'],
#  [409089005, 'Febrile neutropenia (disorder)'],
#  [129721000119106, 'Acute renal failure on dialysis (disorder)'],
#  [79619009, 'Mitral valve stenosis (disorder)'],
#  [278365007, 'Anticoagulant-induced bleeding (disorder)'],
#  [698754002, 'Chronic paralysis due to lesion of spinal cord (disorder)'],
#  [161622006, 'History of lower limb amputation (situation)'],
#  [111287006, 'Tricuspid valve regurgitation (disorder)'],
#  [11218009, 'Infection caused by Pseudomonas aeruginosa (disorder)'],
#  [119481000119105, 'History of aortic valve repair (situation)'],
#  [406602003, 'Infection caused by Staphylococcus aureus (disorder)'],
#  [448417001, 'Sepsis caused by Staphylococcus aureus (disorder)'],
#  [49915006, 'Tricuspid valve stenosis (disorder)'],
#  [414564002, 'Kyphosis deformity of spine (disorder)'],
#  [230745008, 'Hydrocephalus (disorder)'],
#  [1003755004, 'Allergy to Hevea brasiliensis latex protein (finding)'],
#  [6471006, 'Suicidal thoughts (finding)'],
#  [287182007, 'Attempted suicide - suffocation (event)'],
#  [267064002, 'Retention of urine (disorder)'],
#  [76916001, 'Spina bifida occulta (disorder)'],
#  [86849004, 'Suicidal poisoning (disorder)'],
#  [448813005, 'Sepsis caused by Pseudomonas (disorder)'],
#  [225444004, 'At increased risk for suicide (finding)'],
#  [206523001, 'Meconium ileus (disorder)'],
#  [287185009, 'Attempted suicide - cut/stab (event)'],
#  [47200007, 'High risk pregnancy (finding)'],
#  [200936003, 'Lupus erythematosus (disorder)'],
#  [120991000119102,
#   'History of undergoing in utero procedure while a fetus (situation)'],
#  [275408006, 'Postoperative renal failure (disorder)'],
#  [47318007, 'Drug-induced neutropenia (disorder)'],
#  [5758002, 'Bacteremia (finding)'],
#  [171131006, 'Meningocele (disorder)'],
#  [698423002, 'History of disarticulation at wrist (situation)'],
#  [161621004, 'History of upper limb amputation (situation)'],
#  [129574000, 'Postoperative myocardial infarction (disorder)'],
#  [55680006, 'Drug overdose (disorder)']]
